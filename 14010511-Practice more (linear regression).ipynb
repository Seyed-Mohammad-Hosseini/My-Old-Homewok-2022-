# %%
from sklearn.metrics import mean_squared_error

Actual_Value = [2, 4, 3, 2, 5, 6, 7]
Predicted_Value = [2, 3.5, 2.7, 2, 4.3, 6, 7.5]

mean_squared_error(Actual_Value, Predicted_Value)
# Out:
# 0.1542857142857143

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('effects-of-covid-19-on-trade-at-15-december-2021-provisional.csv')
df.head()
# Out:
#   Direction  Year        Date   Weekday Country Commodity Transport_Mode  \
# 0   Exports  2015  01/01/2015  Thursday     All       All            All
# 1   Exports  2015  02/01/2015    Friday     All       All            All
# 2   Exports  2015  03/01/2015  Saturday     All       All            All
# 3   Exports  2015  04/01/2015    Sunday     All       All            All
# 4   Exports  2015  05/01/2015    Monday     All       All            All
#
#   Measure      Value  Cumulative
# 0       $  104000000   104000000
# 1       $   96000000   200000000
# 2       $   61000000   262000000
# 3       $   74000000   336000000
# 4       $  105000000   442000000

# %%
df=pd.read_csv('serious-injury-outcome-indicators-2000-2020-CSV.csv')
df.head()
# Out:
#   Series_reference   Period            Type  Data_value   Lower_CI   Upper_CI  \
# 0            W_A11  2000-02  Moving average   59.666667  50.925823  68.407510
# 1            W_A11  2001-03  Moving average   60.000000  51.234775  68.765225
# 2            W_A11  2002-04  Moving average   59.000000  50.308125  67.691875
# 3            W_A11  2003-05  Moving average   59.000000  50.308125  67.691875
# 4            W_A11  2004-06  Moving average   61.333333  52.471252  70.195415
#
#       Units Indicator    Cause Validation Population       Age Severity
# 0  Injuries    Number  Assault  Validated  Whole pop  All ages    Fatal
# 1  Injuries    Number  Assault  Validated  Whole pop  All ages    Fatal
# 2  Injuries    Number  Assault  Validated  Whole pop  All ages    Fatal
# 3  Injuries    Number  Assault  Validated  Whole pop  All ages    Fatal
# 4  Injuries    Number  Assault  Validated  Whole pop  All ages    Fatal

# %%
df=pd.read_csv('food-price-index-june-2022-index-numbers-csv.csv')
df.head()
# Out:
#   Series_reference   Period  Data_value STATUS  UNITS  \
# 0       CPIM.SE901  1960.01   45.923461  FINAL  Index
# 1       CPIM.SE901  1960.02   45.498637  FINAL  Index
# 2       CPIM.SE901  1960.03   45.116296  FINAL  Index
# 3       CPIM.SE901  1960.04   45.158779  FINAL  Index
# 4       CPIM.SE901  1960.05   45.286226  FINAL  Index
#
#                        Subject                             Group  \
# 0  Consumers Price Index - CPI  Food Price Index for New Zealand
# 1  Consumers Price Index - CPI  Food Price Index for New Zealand
# 2  Consumers Price Index - CPI  Food Price Index for New Zealand
# 3  Consumers Price Index - CPI  Food Price Index for New Zealand
# 4  Consumers Price Index - CPI  Food Price Index for New Zealand
#
#   Series_title_1
# 0           Food
# 1           Food
# 2           Food
# 3           Food
# 4           Food

# %%
df=pd.read_csv('analysis-public-place-assaults-sexual-assaults-and-robberies-2015-csv.csv')
df.head()
# Out:
#    Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0      1               514102            Auckland Central West
# 1      2               573101  Willis Street-Cambridge Terrace
# 2      3               529700                 Hamilton Central
# 3      4               514103            Auckland Central East
# 4      5               591500                 Cathedral Square
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 1                                447                       8300
# 2                                380                       3170
# 3                                375                      13250
# 4                                305                        570
#
#    Rate_per_10000_population   Rate_ratio_NZ_average_rate   \
# 0                         346                          6.6
# 1                         539                         10.3
# ...

# %%
cdf=df[['Population_mid_point_2015','Territorial_authority_area_2013_code']]
cdf.head()
# Out:
#    Population_mid_point_2015  Territorial_authority_area_2013_code
# 0                      15900                                    76
# 1                       8300                                    47
# 2                       3170                                    16
# 3                      13250                                    76
# 4                        570                                    60

# %%
plt.scatter('Population_mid_point_2015', 'Territorial_authority_area_2013_code')
plt.show()

# %%
df=pd.read_csv('FuelConsumption.csv')
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
cdf=df[['FUELCONSUMPTION_CITY','CO2EMISSIONS']]
cdf.head()
# Out:
#    FUELCONSUMPTION_CITY  CO2EMISSIONS
# 0                   9.9           196
# 1                  11.2           221
# 2                   6.0           136
# 3                  12.7           255
# 4                  12.1           244

# %%
plt.scatter(cdf.FUELCONSUMPTION_CITY, cdf.CO2EMISSIONS, color='red')
plt.show()

# %%
msk= np.random.rand(len(cdf)) <0.8

train=cdf[msk]
test=cdf[~msk]

test.head()
# Out:
#     FUELCONSUMPTION_CITY  CO2EMISSIONS
# 0                    9.9           196
# 2                    6.0           136
# 4                   12.1           244
# 6                   11.8           232
# 10                  11.2           225

# %%
plt.scatter(cdf.FUELCONSUMPTION_CITY, cdf.CO2EMISSIONS, color='magenta')
plt.xlabel('FUEL')
plt.ylabel('CO2')
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()

train_x=np.asanyarray(train[['FUELCONSUMPTION_CITY']])
train_y=np.asanyarray(train[['CO2EMISSIONS']])

regr.fit(train_x,train_y)

print('regression coefficient= ', regr.coef_)
print('intercept= ', regr.intercept_)
# Out:
# regression coefficient=  [[13.78210525]]
# intercept=  [74.60880778]

# %%
plt.scatter(train.FUELCONSUMPTION_CITY, train.CO2EMISSIONS,  color='blue')
plt.plot(train_x, regr.coef_[0][0] *train_x + regr.intercept_[0], '-r')

plt.xlabel("FUELCONSUMPTION_CITY")
plt.ylabel("Emission")
# Out:
# Text(0, 0.5, 'Emission')

# %%
from sklearn.metrics import r2_score

test_x=np.asanyarray(test[['FUELCONSUMPTION_CITY']])
test_y=np.asanyarray(test[['CO2EMISSIONS']])

test_y_=regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y , test_y_) )
# Out:
# Mean absolute error: 19.60
# Residual sum of squares (MSE): 790.75
# R2-score: 0.81

# %%
#این تست رو خودم انجام دادم و مشخص شد مصرف سوخت درون شهر و الودکی رابطه قوی تری نسبت به حجم موتور و الودگی دارد که جادی گفته بود
